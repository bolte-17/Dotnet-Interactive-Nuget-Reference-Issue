// %% [markdown]
// Manually changing kernel to F#, either in Jupyter or by manually editing the .ipynb file metadata, and removing the `#!fsharp` directive fixes the problem:

// %%
#r "nuget: FSharp.Data"
open FSharp.Data

Http.RequestString "http://example.com"
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-3324.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
// ...
